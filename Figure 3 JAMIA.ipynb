# %% [markdown]
# **Figures and manuscript**

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

pd.set_option('display.max_rows', None)

# %% [markdown]
# # Data

# %%
cols_of_interest = ['input file name', 'correct diagnosis', 'gpt diagnosis', 'Score (0-5)', 'Rank', 'Score (Peter)', 'Score (Justin)', 'Range']

fpath_narrative = 'data/NATMED ChatGPT4 Diagnosis - text without discussion - txt_cases_results.tsv'
narrative = pd.read_csv(fpath_narrative, sep='\t', usecols=cols_of_interest)
narrative['Src'] = 'nar'
narrative.head(2)
# Out:
#                             input file name  \
# 0  PMID_33471980-txt_without_discussion.txt
# 1  PMID_33497551-txt_without_discussion.txt
#
#                                    correct diagnosis  \
# 0  Pregnancy-associated myocardial infarction, pr...
# 1              Mycobacterium tuberculosis meningitis
#
#                                        gpt diagnosis  Score (0-5)  Rank  \
# 0  Most Likely Diagnosis: Peripartum cardiomyopat...          3.0   2.0
# 1  Most Likely Diagnosis: Chronic kidney disease ...          2.0   9.0
#
#    Score (Peter)  Score (Justin)  Range  Src
# 0            3.0             3.0      0  nar
# 1            2.0             2.0      0  nar

# %%
fpath_signs_symptoms = 'data/NATMED ChatGPT4 Diagnosis - phenopacket time based queries - txt_cases_results.tsv'
signs_symptoms = pd.read_csv(fpath_signs_symptoms, sep='\t', usecols=cols_of_interest)
signs_symptoms['Src'] = 'ss'
signs_symptoms.head(2)
# Out:
#                                     input file name  \
# 0  PMID_33471980-phenopacket_time_based_queries.txt
# 1  PMID_33497551-phenopacket_time_based_queries.txt
#
#                                    correct diagnosis  \
# 0  Pregnancy-associated myocardial infarction, pr...
# 1              Mycobacterium tuberculosis meningitis
#
#                                        gpt diagnosis  Score (0-5)  Rank  \
# 0  Most Likely Diagnosis: Peripartum cardiomyopat...          2.0   1.0
# 1  Most likely diagnosis: Congestive Heart Failur...          3.0  12.0
#
#    Score (Peter)  Score (Justin)  Range Src
# 0            2.0             2.0      0  ss
# 1            3.0             3.0      0  ss

# %%
fpath_signs_symptoms = 'data/NATMED ChatGPT4 Diagnosis - text with manual annotation - txt_cases_results.tsv'
manual_annot = pd.read_csv(fpath_signs_symptoms, sep='\t', usecols=cols_of_interest)
manual_annot['Src'] = 'ma'
manual_annot.head(2)
# Out:
#                             input file name  \
# 0  PMID_33471980-txt_with_manual_annots.txt
# 1  PMID_33497551-txt_with_manual_annots.txt
#
#                                    correct diagnosis  \
# 0  Pregnancy-associated myocardial infarction, pr...
# 1              Mycobacterium tuberculosis meningitis
#
#                                        gpt diagnosis  Score (0-5)  Rank  \
# 0  Most likely diagnosis: Peripartum cardiomyopat...          2.0   1.0
# 1  Most Likely Diagnosis: Disseminated Tuberculos...          4.0   1.0
#
#    Score (Peter)  Score (Justin)  Range Src
# 0            2.0             2.0      0  ma
# 1            4.0             4.0      0  ma

# %%
cols = ['input file name', 'Src', 'Score (0-5)', 'Rank']
df = pd.concat([narrative[cols], signs_symptoms[cols], manual_annot[cols]]).sort_index().rename(columns={'Score (0-5)':'Score'})
df
# Out:
# 68  PMID_36383716-phenopacket_time_based_queries.txt   ss    4.0   1.0
# 68          PMID_36383716-txt_without_discussion.txt  nar    3.0   1.0
# 69          PMID_36416771-txt_without_discussion.txt  nar    0.0  -1.0
# 69          PMID_36416771-txt_with_manual_annots.txt   ma    0.0  -1.0
# 69  PMID_36416771-phenopacket_time_based_queries.txt   ss    0.0  -1.0
# 70          PMID_36477035-txt_with_manual_annots.txt   ma    0.0  -1.0
# 70  PMID_36477035-phenopacket_time_based_queries.txt   ss    3.0  10.0
# 70          PMID_36477035-txt_without_discussion.txt  nar    5.0   1.0
# 71          PMID_36516093-txt_without_discussion.txt  nar    2.0  11.0
# 71          PMID_36516093-txt_with_manual_annots.txt   ma    0.0  -1.0
# 71  PMID_36516093-phenopacket_time_based_queries.txt   ss    0.0  -1.0
# 72          PMID_36546630-txt_with_manual_annots.txt   ma    0.0  -1.0
# 72  PMID_36546630-phenopacket_time_based_queries.txt   ss    0.0  -1.0
# 72          PMID_36546630-txt_without_discussion.txt  nar    0.0  -1.0
# 73          PMID_36577103-txt_with_manual_annots.txt   ma    0.0  -1.0
# 73  PMID_36577103-phenopacket_time_based_queries.txt   ss    0.0  -1.0
# 73          PMID_36577103-txt_without_discussion.txt  nar    0.0  -1.0
# 74                                               NaN  nar    NaN   NaN
# 74                                               NaN   ss    NaN   NaN
# 74                                               NaN   ma    NaN   NaN

# %% [markdown]
# Skip the cases where the score is N/A

# %%
print(df.loc[df.Score.isna()])
df = df.loc[~df.Score.isna()]
# Out:
#    input file name  Src  Score  Rank
# 74             NaN  nar    NaN   NaN
# 74             NaN   ss    NaN   NaN
# 74             NaN   ma    NaN   NaN

# %% [markdown]
# Convert to `str`s

# %%
df = df.astype({'Score': int, 'Rank': int})
df
# Out:
#                                      input file name  Src  Score  Rank
# 0           PMID_33471980-txt_without_discussion.txt  nar      3     2
# 0   PMID_33471980-phenopacket_time_based_queries.txt   ss      2     1
# 0           PMID_33471980-txt_with_manual_annots.txt   ma      2     1
# 1           PMID_33497551-txt_without_discussion.txt  nar      2     9
# 1   PMID_33497551-phenopacket_time_based_queries.txt   ss      3    12
# 1           PMID_33497551-txt_with_manual_annots.txt   ma      4     1
# 2           PMID_33503346-txt_without_discussion.txt  nar      0    -1
# 2   PMID_33503346-phenopacket_time_based_queries.txt   ss      0    -1
# 2           PMID_33503346-txt_with_manual_annots.txt   ma      0    -1
# 3           PMID_33567196-txt_without_discussion.txt  nar      0    -1
# 3   PMID_33567196-phenopacket_time_based_queries.txt   ss      0    -1
# 3           PMID_33567196-txt_with_manual_annots.txt   ma      0    -1
# 4           PMID_33596360-txt_without_discussion.txt  nar      0    -1
# 4   PMID_33596360-phenopacket_time_based_queries.txt   ss      0    -1
# 4           PMID_33596360-txt_with_manual_annots.txt   ma      0    -1
# 5   PMID_33626257-phenopacket_time_based_queries.txt   ss      0    -1
# 5           PMID_33626257-txt_with_manual_annots.txt   ma      5     1
# 5           PMID_33626257-txt_without_discussion.txt  nar      5     1
# 21          PMID_34379926-txt_without_discussion.txt  nar      4     7
# 21  PMID_34379926-phenopacket_time_based_queries.txt   ss      0    -1
# 22          PMID_34407347-txt_with_manual_annots.txt   ma      0    -1
# 22          PMID_34407347-txt_without_discussion.txt  nar      5     6
# 22  PMID_34407347-phenopacket_time_based_queries.txt   ss      0    -1
# 23          PMID_34437787-txt_with_manual_annots.txt   ma      4     1
# 23          PMID_34437787-txt_without_discussion.txt  nar      4     1
# 23  PMID_34437787-phenopacket_time_based_queries.txt   ss      4     1
# 24          PMID_34525289-txt_without_discussion.txt  nar      5     5
# 24  PMID_34525289-phenopacket_time_based_queries.txt   ss      4     1
# 24          PMID_34525289-txt_with_manual_annots.txt   ma      4     1
# 25  PMID_34551232-phenopacket_time_based_queries.txt   ss      4     9
# 25          PMID_34551232-txt_with_manual_annots.txt   ma      4     7
# 25          PMID_34551232-txt_without_discussion.txt  nar      5     7
# 26  PMID_34644476-phenopacket_time_based_queries.txt   ss      3     7
# 26          PMID_34644476-txt_with_manual_annots.txt   ma      3     2
# 26          PMID_34644476-txt_without_discussion.txt  nar      4     3
# 27  PMID_34706175-phenopacket_time_based_queries.txt   ss      0    -1
# 27          PMID_34706175-txt_with_manual_annots.txt   ma      0    -1
# 27          PMID_34706175-txt_without_discussion.txt  nar      0    -1
# 28  PMID_34758256-phenopacket_time_based_queries.txt   ss      0    -1
# 28          PMID_34758256-txt_without_discussion.txt  nar      5     1
# 28          PMID_34758256-txt_with_manual_annots.txt   ma      2    -1
# 29          PMID_34788511-txt_without_discussion.txt  nar      0    -1
# 29  PMID_34788511-phenopacket_time_based_queries.txt   ss      4     1
# 29          PMID_34788511-txt_with_manual_annots.txt   ma      0    -1
# 30          PMID_34818483-txt_without_discussion.txt  nar      4    10
# 30  PMID_34818483-phenopacket_time_based_queries.txt   ss      4     5
# 30          PMID_34818483-txt_with_manual_annots.txt   ma      4     5
# 31          PMID_34910867-txt_without_discussion.txt  nar      0    -1
# 31  PMID_34910867-phenopacket_time_based_queries.txt   ss      0    -1
# 31          PMID_34910867-txt_with_manual_annots.txt   ma      0    -1
# 32          PMID_34936743-txt_without_discussion.txt  nar      3     3
# 32  PMID_34936743-phenopacket_time_based_queries.txt   ss      4     4
# 32          PMID_34936743-txt_with_manual_annots.txt   ma      5     1
# 33  PMID_34965341-phenopacket_time_based_queries.txt   ss      0    -1
# 33          PMID_34965341-txt_with_manual_annots.txt   ma      0    -1
# 33          PMID_34965341-txt_without_discussion.txt  nar      0    -1
# 34          PMID_35020988-txt_with_manual_annots.txt   ma      0    -1
# 34          PMID_35020988-txt_without_discussion.txt  nar      0    -1
# 34  PMID_35020988-phenopacket_time_based_queries.txt   ss      0    -1
# 35          PMID_35045230-txt_with_manual_annots.txt   ma      0    -1
# 35          PMID_35045230-txt_without_discussion.txt  nar      0    -1
# 35  PMID_35045230-phenopacket_time_based_queries.txt   ss      0    -1
# 36          PMID_35081284-txt_with_manual_annots.txt   ma      5     1
# 36          PMID_35081284-txt_without_discussion.txt  nar      4    15
# 36  PMID_35081284-phenopacket_time_based_queries.txt   ss      4     2
# 37          PMID_35139277-txt_with_manual_annots.txt   ma      5     2
# 37  PMID_35139277-phenopacket_time_based_queries.txt   ss      5    10
# 37          PMID_35139277-txt_without_discussion.txt  nar      5     4
# 38  PMID_35172059-phenopacket_time_based_queries.txt   ss      4     6
# 38          PMID_35172059-txt_with_manual_annots.txt   ma      4     5
# 38          PMID_35172059-txt_without_discussion.txt  nar      0    -1
# 39  PMID_35196431-phenopacket_time_based_queries.txt   ss      2     2
# 39          PMID_35196431-txt_with_manual_annots.txt   ma      0    -1
# 39          PMID_35196431-txt_without_discussion.txt  nar      5     1
# 40  PMID_35263523-phenopacket_time_based_queries.txt   ss      0    -1
# 40          PMID_35263523-txt_with_manual_annots.txt   ma      0    -1
# 40          PMID_35263523-txt_without_discussion.txt  nar      0    -1
# 41  PMID_35294816-phenopacket_time_based_queries.txt   ss      0    -1
# 41          PMID_35294816-txt_with_manual_annots.txt   ma      4    14
# 41          PMID_35294816-txt_without_discussion.txt  nar      4     1
# 42          PMID_35320647-txt_with_manual_annots.txt   ma      0    -1
# 42          PMID_35320647-txt_without_discussion.txt  nar      0    -1
# 42  PMID_35320647-phenopacket_time_based_queries.txt   ss      0    -1
# 43          PMID_35353965-txt_without_discussion.txt  nar      5     1
# 43  PMID_35353965-phenopacket_time_based_queries.txt   ss      5     7
# 43          PMID_35353965-txt_with_manual_annots.txt   ma      5     4
# 44          PMID_35417641-txt_without_discussion.txt  nar      5     5
# 44  PMID_35417641-phenopacket_time_based_queries.txt   ss      5    11
# 44          PMID_35417641-txt_with_manual_annots.txt   ma      0    -1
# 45          PMID_35443111-txt_without_discussion.txt  nar      4     6
# 45  PMID_35443111-phenopacket_time_based_queries.txt   ss      4     7
# 45          PMID_35443111-txt_with_manual_annots.txt   ma      4     3
# 46          PMID_35476654-txt_without_discussion.txt  nar      3     5
# 46  PMID_35476654-phenopacket_time_based_queries.txt   ss      2    -1
# 46          PMID_35476654-txt_with_manual_annots.txt   ma      0    -1
# 47          PMID_35544390-txt_without_discussion.txt  nar      3     8
# 47          PMID_35544390-txt_with_manual_annots.txt   ma      0    -1
# 47  PMID_35544390-phenopacket_time_based_queries.txt   ss      2    16
# 48          PMID_35584159-txt_with_manual_annots.txt   ma      4     8
# 48          PMID_35584159-txt_without_discussion.txt  nar      0    -1
# 48  PMID_35584159-phenopacket_time_based_queries.txt   ss      0    -1
# 49          PMID_35613025-txt_with_manual_annots.txt   ma      4    11
# 49          PMID_35613025-txt_without_discussion.txt  nar      4     5
# 49  PMID_35613025-phenopacket_time_based_queries.txt   ss      4    10
# 50          PMID_35675180-txt_with_manual_annots.txt   ma      2    11
# 50          PMID_35675180-txt_without_discussion.txt  nar      0    -1
# 50  PMID_35675180-phenopacket_time_based_queries.txt   ss      0    -1
# 51          PMID_35704401-txt_with_manual_annots.txt   ma      0    -1
# 51          PMID_35704401-txt_without_discussion.txt  nar      0    -1
# 51  PMID_35704401-phenopacket_time_based_queries.txt   ss      0    -1
# 67          PMID_36351271-txt_without_discussion.txt  nar      5     1
# 67          PMID_36351271-txt_with_manual_annots.txt   ma      5     1
# 68          PMID_36383716-txt_with_manual_annots.txt   ma      4     3
# 68  PMID_36383716-phenopacket_time_based_queries.txt   ss      4     1
# 68          PMID_36383716-txt_without_discussion.txt  nar      3     1
# 69          PMID_36416771-txt_without_discussion.txt  nar      0    -1
# 69          PMID_36416771-txt_with_manual_annots.txt   ma      0    -1
# 69  PMID_36416771-phenopacket_time_based_queries.txt   ss      0    -1
# 70          PMID_36477035-txt_with_manual_annots.txt   ma      0    -1
# 70  PMID_36477035-phenopacket_time_based_queries.txt   ss      3    10
# 70          PMID_36477035-txt_without_discussion.txt  nar      5     1
# 71          PMID_36516093-txt_without_discussion.txt  nar      2    11
# 71          PMID_36516093-txt_with_manual_annots.txt   ma      0    -1
# 71  PMID_36516093-phenopacket_time_based_queries.txt   ss      0    -1
# 72          PMID_36546630-txt_with_manual_annots.txt   ma      0    -1
# 72  PMID_36546630-phenopacket_time_based_queries.txt   ss      0    -1
# 72          PMID_36546630-txt_without_discussion.txt  nar      0    -1
# 73          PMID_36577103-txt_with_manual_annots.txt   ma      0    -1
# 73  PMID_36577103-phenopacket_time_based_queries.txt   ss      0    -1
# 73          PMID_36577103-txt_without_discussion.txt  nar      0    -1

# %% [markdown]
# # Plot histogram of scores

# %%
# fix weird matplotlib legend ordering
import numpy as np
def reorderLegend(ax=None,order=None,unique=False):
    if ax is None: ax=plt.gca()
    handles, labels = ax.get_legend_handles_labels()
    labels, handles = zip(*sorted(zip(labels, handles), key=lambda t: t[0])) # sort both labels and handles by labels
    if order is not None: # Sort according to a given list (not necessarily complete)
        keys=dict(zip(order,range(len(order))))
        labels, handles = zip(*sorted(zip(labels, handles), key=lambda t,keys=keys: keys.get(t[0],np.inf)))
    if unique:  labels, handles= zip(*unique_everseen(zip(labels,handles), key = labels)) # Keep only the first of each handle
    ax.legend(handles, labels)
    return(handles, labels)


def unique_everseen(seq, key=None):
    seen = set()
    seen_add = seen.add
    return [x for x,k in zip(seq,key) if not (k in seen or seen_add(k))]

# %%
fig, ax = plt.subplots(figsize=(6,4.5), dpi=120)

data = df.astype({'Score': str}).groupby(['Src', 'Score'], sort=True).size()
data.name='Count'
data = data.reset_index()
data
# Out:
#     Src Score  Count
# 0    ma     0     35
# 1    ma     2      4
# 2    ma     3      5
# 3    ma     4     20
# 4    ma     5     10
# 5   nar     0     27
# 6   nar     2      6
# 7   nar     3     10
# 8   nar     4     15
# 9   nar     5     16
# 10   ss     0     32
# 11   ss     2      8
# 12   ss     3      7
# 13   ss     4     19
# 14   ss     5      8

# %%
fig, ax = plt.subplots(figsize=(6,4.5), dpi=120)

data = df.astype({'Score': str}).groupby(['Src', 'Score'], sort=True).size()
data.name='Count'
data = data.reset_index()

sns.barplot(data=data, x='Score', y='Count', hue='Src', 
            palette=['#3465a4', '#fcaf3e', 'black'],
            hue_order=['nar', 'ss', 'ma'],
            ax=ax)
ax.grid(axis='y')
ax.set(ylim=(0, 70))
ax.legend_.set(title=None)

ax.legend_.get_texts()[0].set(text='Narrative-based queries')
ax.legend_.get_texts()[1].set(text='Feature-based queries')
ax.legend_.get_texts()[2].set(text='Manual annotation')


fig.tight_layout()
fig.savefig('Fig3A.png')

# %% [markdown]
# # Plot histogram of the ranks of the correct diagnoses

# %%
ranks = df.loc[df.Score >= 4, ['Src', 'Rank']]
rank_bins = [0, 1, 2, 3, 4, 9, 100]
rank_labels = ['1', '2', '3', '4', '5-9', '≥10']

ranks['RankLabel'] = pd.cut(ranks.Rank, bins=rank_bins, labels=rank_labels)
ranks.head(2)
# Out:
#   Src  Rank RankLabel
# 1  ma     1         1
# 5  ma     1         1

# %%
fig, ax = plt.subplots(figsize=(6,4.5), dpi=120)

data = ranks.groupby(['Src', 'RankLabel']).size()
data.name = 'Count'
unranked = df.loc[df.Score <4, ['Src', 'Rank']].groupby('Src').size()
data.loc['ss', 'Unranked'] = unranked.loc['ss']
data.loc['nar', 'Unranked'] = unranked.loc['nar']
data.loc['ma', 'Unranked'] = unranked.loc['ma']
data = data.reset_index()

sns.barplot(data=data, x='RankLabel', y='Count', hue='Src', 
            palette=['#3465a4', '#fcaf3e', 'black'],# c.orange],
            hue_order=['nar', 'ss', 'ma'],
            ax=ax)
ax.grid(axis='y')
ax.set(xlabel='Rank', ylim=(0, 50))
ax.legend_.set(title=None)
# ax.legend_.get_texts()[0].set(text='Narrative-based queries')
# ax.legend_.get_texts()[1].set(text='Feature-based queries')
fig.tight_layout()
fig.savefig('Fig3B.png')

# %% [markdown]
# # The entire figure

# %%
fig, (l, r) = plt.subplots(1, 2, figsize=(12, 4.5), dpi=120, sharey=True)

# (A)
data = df.astype({'Score': str}).groupby(['Src', 'Score']).size()
data.name = 'No. of cases'
data = data.reset_index()

sns.barplot(data=data, x='Score', y='No. of cases', hue='Src', 
            palette=['#3465a4', '#fcaf3e', 'black'],
            hue_order=['nar', 'ss', 'ma'],
            ax=l)
l.grid(axis='y')
l.set(ylim=(0, 47))
l.legend_.set(title=None)
l.legend_.get_texts()[0].set(text='Narrative-based queries')
l.legend_.get_texts()[1].set(text='Feature-based queries')
l.legend_.get_texts()[2].set(text='Manual annotation')

# (B)
data = ranks.groupby(['Src', 'RankLabel']).size()
data.name = 'No. of cases'
unranked = df.loc[df.Score <4, ['Src', 'Rank']].groupby('Src').size()
data.loc['ss', 'Unranked'] = unranked.loc['ss']
data.loc['nar', 'Unranked'] = unranked.loc['nar']
data.loc['ma', 'Unranked'] = unranked.loc['ma']
data = data.reset_index()

sns.barplot(data=data, x='RankLabel', y='No. of cases', hue='Src', 
            palette=['#3465a4', '#fcaf3e', 'black'],# c.orange],
            hue_order=['nar', 'ss', 'ma'],
            ax=r)
r.grid(axis='y')
r.set(xlabel='Rank', ylabel=None)
r.legend_.set(visible=False)

fig.tight_layout()
fig.savefig('Figure3.raw.svg')

# %% [markdown]
# Postprocess in Inkscape to increase horizontal space between the panels and to add panel labels.

# %% [markdown]
# Done
